# %%
#reading in data
import pandas as pd 

df_pIC50= pd.read_csv('/Users/michael/Documents/Bioinformatics/Personal_Projects/ML/Drug_discovery/Drug_Discovery/project2/HDAC_data_pIC50.csv')

df_pIC50
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL323869  O=C(CCCCCC(NC(=O)OCc1ccccc1)C(=O)Nc1cccc2cccnc...
# 1          CHEMBL327146  O=C(CCCCCC(C(=O)Nc1ccc2ncccc2c1)C(=O)Nc1ccc2nc...
# 2          CHEMBL116620  O=C(/C=C/c1cccc(C(C(=O)Nc2ccccc2)C(=O)Nc2ccccc...
# 3              CHEMBL98                        O=C(CCCCCCC(=O)Nc1ccccc1)NO
# 4          CHEMBL346414  Cc1ccc(NS(=O)(=O)c2ccc(/C=C/C(=O)Nc3ccccc3N)cc...
# ...                 ...                                                ...
# 8867      CHEMBL5432574  O=C(CCCCCCNC(=O)c1ccc(NC(=O)CC23C[C@H]4C[C@@H]...
# 8868      CHEMBL5436873  O=C(CCCCCCNC(=O)c1ccc(NC(=O)CNC(=O)CC23C[C@H]4...
# 8869      CHEMBL5434895  O=C(CCCCCCNC(=O)c1ccc(NC(=O)CNC(=O)CC2c3ccccc3...
# 8870      CHEMBL5414971  O=C(CCCCCCNC(=O)c1ccc(-c2cn(CCCCCCOCCOCCNC(=O)...
# 8871           CHEMBL98                        O=C(CCCCCCC(=O)Nc1ccccc1)NO
#
#            MW     LogP  NumHDonors  NumHAcceptors     pIC50
# ...

# %%
cols_of_int = ['canonical_smiles', 'molecule_chembl_id']
df_pIC50_fil = df_pIC50[cols_of_int]
df_pIC50_fil
# Out:
#                                        canonical_smiles molecule_chembl_id
# 0     O=C(CCCCCC(NC(=O)OCc1ccccc1)C(=O)Nc1cccc2cccnc...       CHEMBL323869
# 1     O=C(CCCCCC(C(=O)Nc1ccc2ncccc2c1)C(=O)Nc1ccc2nc...       CHEMBL327146
# 2     O=C(/C=C/c1cccc(C(C(=O)Nc2ccccc2)C(=O)Nc2ccccc...       CHEMBL116620
# 3                           O=C(CCCCCCC(=O)Nc1ccccc1)NO           CHEMBL98
# 4     Cc1ccc(NS(=O)(=O)c2ccc(/C=C/C(=O)Nc3ccccc3N)cc...       CHEMBL346414
# ...                                                 ...                ...
# 8867  O=C(CCCCCCNC(=O)c1ccc(NC(=O)CC23C[C@H]4C[C@@H]...      CHEMBL5432574
# 8868  O=C(CCCCCCNC(=O)c1ccc(NC(=O)CNC(=O)CC23C[C@H]4...      CHEMBL5436873
# 8869  O=C(CCCCCCNC(=O)c1ccc(NC(=O)CNC(=O)CC2c3ccccc3...      CHEMBL5434895
# 8870  O=C(CCCCCCNC(=O)c1ccc(-c2cn(CCCCCCOCCOCCNC(=O)...      CHEMBL5414971
# 8871                        O=C(CCCCCCC(=O)Nc1ccccc1)NO           CHEMBL98
#
# [8872 rows x 2 columns]

# %%
df_pIC50_fil.to_csv('/Users/michael/Documents/Bioinformatics/Personal_Projects/ML/Drug_discovery/Drug_Discovery/project2/molecule.smi', sep='\t', index=False, header=False)

# %%
# !cat /Users/michael/Documents/Bioinformatics/Personal_Projects/ML/Drug_discovery/Drug_Discovery/project2/molecule.smi | wc -l
# Out:
#     8872

# %%
# !bash run_padel.sh
# Out:
# Processing CHEMBL323869 in molecule.smi (1/8872).
# Processing CHEMBL327146 in molecule.smi (2/8872).
# Processing CHEMBL116620 in molecule.smi (3/8872).
# Processing CHEMBL98 in molecule.smi (4/8872).
# Processing CHEMBL346414 in molecule.smi (5/8872).
# Processing CHEMBL95552 in molecule.smi (6/8872).
# Processing CHEMBL97387 in molecule.smi (7/8872).
# Processing CHEMBL95835 in molecule.smi (8/8872).
# Processing CHEMBL97632 in molecule.smi (9/8872). Average speed: 3.10 s/mol.
# Processing CHEMBL99810 in molecule.smi (11/8872). Average speed: 1.06 s/mol.
# Processing CHEMBL317570 in molecule.smi (10/8872). Average speed: 3.11 s/mol.
# Processing CHEMBL98346 in molecule.smi (12/8872). Average speed: 0.81 s/mol.
# Processing CHEMBL145891 in molecule.smi (13/8872). Average speed: 0.66 s/mol.
# Processing CHEMBL95959 in molecule.smi (14/8872). Average speed: 0.55 s/mol.
# Processing CHEMBL100035 in molecule.smi (15/8872). Average speed: 0.55 s/mol.
# ...
